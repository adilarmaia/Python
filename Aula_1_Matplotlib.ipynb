# %% [markdown]
# <a href="https://colab.research.google.com/github/adilarmaia/Python/blob/main/Aula_1_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x = [1, 3, 5, 7 ,9]
y = [2, 3, 7, 1, 0]

#x1 = [1, 3, 5, 7 ,9]
#y1 = [2, 3, 7, 1, 0]

#x2 = [2, 4, 6, 8, 10] 
#y2 = [5, 1, 3, 7, 4]

titulo = "Gráfico de Barras 2"
eixox = "Eixo X"
eixoy="Eixo Y"

#Legendas 
plt.title(titulo)
plt.xlabel(eixox)
plt.ylabel(eixoy)

plt.scatter(x, y, label="Meus pontos", color="red")
plt.plot(x, y)
#plt.bar(x1, y1, label= "Grupo 1")
#plt.bar(x2, y2, label= "Grupo 2")
plt.legend()
plt.show()
